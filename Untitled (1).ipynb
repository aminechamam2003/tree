# %%
import pandas as pd
df=pd.read_csv("titanic-passengers.csv",sep=";")
df=df.dropna(axis=0,how='any')
df.head()
# Out:
#     PassengerId Survived  Pclass                              Name   Sex  \
# 1            76       No       3           Moen, Mr. Sigurd Hansen  male
# 4           672       No       1            Davidson, Mr. Thornton  male
# 16          378       No       1         Widener, Mr. Harry Elkins  male
# 19          225      Yes       1      Hoyt, Mr. Frederick Maxfield  male
# 26          588      Yes       1  Frolicher-Stehli, Mr. Maxmillian  male
#
#      Age  SibSp  Parch      Ticket    Fare  Cabin Embarked
# 1   25.0      0      0      348123    7.65  F G73        S
# 4   31.0      1      0  F.C. 12750   52.00    B71        S
# 16  27.0      0      2      113503  211.50    C82        C
# 19  38.0      1      0       19943   90.00    C93        S
# 26  60.0      1      1       13567   79.20    B41        C

# %%
d={'Survived':{'No':0,'Yes':1}}
df.replace(d,inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 1             76         0       3           Moen, Mr. Sigurd Hansen    male
# 4            672         0       1            Davidson, Mr. Thornton    male
# 16           378         0       1         Widener, Mr. Harry Elkins    male
# 19           225         1       1      Hoyt, Mr. Frederick Maxfield    male
# 26           588         1       1  Frolicher-Stehli, Mr. Maxmillian    male
# ..           ...       ...     ...                               ...     ...
# 862          619         1       2       Becker, Miss. Marion Louise  female
# 863          858         1       1             Daly, Mr. Peter Denis    male
# 865          196         1       1              Lurette, Miss. Elise  female
# 875          463         0       1                 Gee, Mr. Arthur H    male
# 881          699         0       1          Thayer, Mr. John Borland    male
#
# ...

# %%
d={'Sex':{'male':0,'female':1}}
df.replace(d,inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass                              Name  Sex  \
# 1             76         0       3           Moen, Mr. Sigurd Hansen    0
# 4            672         0       1            Davidson, Mr. Thornton    0
# 16           378         0       1         Widener, Mr. Harry Elkins    0
# 19           225         1       1      Hoyt, Mr. Frederick Maxfield    0
# 26           588         1       1  Frolicher-Stehli, Mr. Maxmillian    0
# ..           ...       ...     ...                               ...  ...
# 862          619         1       2       Becker, Miss. Marion Louise    1
# 863          858         1       1             Daly, Mr. Peter Denis    0
# 865          196         1       1              Lurette, Miss. Elise    1
# 875          463         0       1                 Gee, Mr. Arthur H    0
# 881          699         0       1          Thayer, Mr. John Borland    0
#
#       Age  SibSp  Parch      Ticket      Fare  Cabin Embarked
# ...

# %%
#import relevant libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

#features extraction
x = df[['Pclass', 'Age','Parch']]
y = df['Survived']

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=0)  #splitting data with test size of 25%

logreg = LogisticRegression()   #build our logistic model
logreg.fit(x_train, y_train)  #fitting training data
y_pred  = logreg.predict(x_test)    #testing model’s performance
print("Accuracy={:.2f}".format(logreg.score(x_test, y_test)))
# Out:
# Accuracy=0.70

# %%
#Importing our dataset from csv file
import pandas as pd 
dataset=pd.read_csv("titanic-passengers.csv", sep=";")

#Preprocessing our data
def preprocess_data(new_data):
    new_data['Age'].fillna(new_data['Age'].mean(),inplace=True)
    new_data.replace({'Sex':{'male': 1,'female':0}},inplace=True)
    new_data['Cabin']=new_data.Cabin.fillna('G6')
    new_data.replace({'Survived':{'Yes': 1,'No':0}},inplace=True)
    return new_data
data=preprocess_data(dataset)

# %%
#importing relevant libraries
from sklearn.model_selection import train_test_split
from sklearn import tree   
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
#features extraction
x=data.drop(["Survived", "Name", "Cabin", "Ticket", "Embarked"], axis=1)
y= data["Survived"]

#splitting data
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20,random_state=10)
dtree=tree.DecisionTreeClassifier(criterion="gini",splitter="random",max_leaf_nodes=10,min_samples_leaf=5,max_depth=5,min_impurity_decrease=2)
#applying tree algorithm
model = tree.DecisionTreeClassifier()  
model.fit(x_train, y_train)   #fitting our model
y_pred=model.predict(x_test)   # evaluating our model
print("score:{}".format(accuracy_score(y_test, y_pred)))
# Out:
# score:0.7877094972067039

# %%
x_train
# Out:
#      PassengerId  Pclass  Sex   Age  SibSp  Parch     Fare
# 57           117       3    1  70.5      0      0   7.7500
# 717          478       3    1  29.0      1      0   7.0458
# 431            4       1    0  35.0      1      0  53.1000
# 633           35       1    1  28.0      1      0  82.1708
# 163          859       3    0  24.0      0      3  19.2583
# ..           ...     ...  ...   ...    ...    ...      ...
# 369           52       3    1  21.0      0      0   7.8000
# 320          395       3    0  24.0      0      2  16.7000
# 527           58       3    1  28.5      0      0   7.2292
# 125          314       3    1  28.0      0      0   7.8958
# 265          797       1    0  49.0      0      0  25.9292
#
# [712 rows x 7 columns]

# %%
import graphviz
dot_data = tree.export_graphviz(model, out_file=None) 
graph = graphviz.Source(dot_data)
graph.render("data")
graph

# %%
dtree=tree.DecisionTreeClassifier(criterion="gini",splitter="random",max_leaf_nodes=10,min_samples_leaf=5,max_depth=5,min_impurity_decrease=2)
#applying tree algorithm
dtree = tree.DecisionTreeClassifier()  
dtree.fit(x_train, y_train)   #fitting our model
y_pred=model.predict(x_test)   # evaluating our model
print("score:{}".format(accuracy_score(y_test, y_pred)))
# Out:
# score:0.7877094972067039

# %%
#applying tree algorithm
dtree = tree.DecisionTreeClassifier()  
dtree.fit(x_train, y_train)   #fitting our model
y_pred=model.predict(x_test)   # evaluating our model
print("score:{}".format(accuracy_score(y_test, y_pred)))
# Out:
# score:0.7877094972067039

# %%
import graphviz
dot_data = tree.export_graphviz(model, out_file=None) 
graph = graphviz.Source(dot_data)
graph.render("data")
graph

# %%
#applying tree algorithm
dtree = tree.DecisionTreeClassifier()  
dtree.fit(x_train, y_train)   #fitting our model
y_pred=model.predict(x_test)   # evaluating our model
print("score:{}".format(accuracy_score(y_test, y_pred)))
# Out:
# score:0.7877094972067039

# %%
from sklearn.ensemble import RandomForestClassifier #Importing Random Forest Classifier
from sklearn import metrics  # Importing metrics to test accuracy

clf=RandomForestClassifier(criterion="gini", n_estimators=10, max_depth=3)  #Creating a random forest with 100 decision trees
clf.fit(x_train, y_train)  #Training our model
y_pred=clf.predict(x_test)  #testing our model
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))  #Measuring the accuracy of our model
# Out:
# Accuracy: 0.8156424581005587

# %%
clf=RandomForestClassifier(criterion="gini", n_estimators=20, max_depth=5)  #Creating a random forest with 100 decision trees
clf.fit(x_train, y_train)  #Training our model
y_pred=clf.predict(x_test)  #testing our model
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8156424581005587
